# %%
India_boundary

# %%
import geopandas as gpd
import folium
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyproj\__init__.py:76: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()

# %%
gdf = gpd.read_file('India_boundary.shp')

# %%
gdf
# Out:
#                                             geometry
# 0  MULTIPOLYGON (((84.76858 19.08002, 84.76625 19...

# %%
gdf.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
ind_map = folium.Map(location=[48.856614, 2.3522219], zoom_start=13, tiles='cartodbpositron')

# %%
folium.GeoJson(gdf).add_to(pak_map)
