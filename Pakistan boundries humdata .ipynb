# %%
import geopandas as gpd
import folium
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyproj\__init__.py:76: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()

# %%
import pyproj

# %%
gdf = gpd.read_file('pak_admbnda_adm1_ocha_pco_gaul_20181218.shp')

# %%
gdf
# Out:
#                                             geometry
# 0  POLYGON ((69.87863 31.96020, 69.87382 31.94636...
# 1  POLYGON ((73.19828 33.79771, 73.22183 33.79422...
# 2  POLYGON ((73.65503 36.90857, 73.66257 36.89641...
# 3  MULTIPOLYGON (((69.55326 28.13298, 69.55127 28...
# 4  MULTIPOLYGON (((68.18577 23.83741, 68.19128 23...

# %%
gdf.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
pak_map = folium.Map(location=[48.856614, 2.3522219], zoom_start=13, tiles='cartodbpositron')

# %%
folium.GeoJson(gdf).add_to(pak_map)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-a85448d010e9> in <module>
# ----> 1 folium.GeoJson(gdf).add_to(pak_map)
#
# C:\ProgramData\Anaconda3\lib\site-packages\folium\features.py in __init__(self, data, style_function, highlight_function, name, overlay, control, show, smooth_factor, tooltip, embed, popup, zoom_on_click, marker)
#     497         self.marker = marker
#     498
# --> 499         self.data = self.process_data(data)
#     500
#     501         if self.style or self.highlight:
#
# C:\ProgramData\Anaconda3\lib\site-packages\folium\features.py in process_data(self, data)
#     539             self.embed = True
#     540             if hasattr(data, 'to_crs'):
# --> 541                 data = data.to_crs('EPSG:4326')
#     542             return json.loads(json.dumps(data.__geo_interface__))
#     543         else:
#
# ...

# %%
gdf.crs = "EPSG:4326"
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# <ipython-input-10-e75a3dab071a> in <module>
# ----> 1 gdf.crs = "EPSG:4326"
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py in __setattr__(self, attr, val)
#     180             object.__setattr__(self, attr, val)
#     181         else:
# --> 182             super(GeoDataFrame, self).__setattr__(attr, val)
#     183
#     184     def _get_geometry(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py in crs(self, value)
#     398         else:
# ...
